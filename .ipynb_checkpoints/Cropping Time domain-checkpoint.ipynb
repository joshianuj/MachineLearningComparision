# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def separate_data_points(file_location):
    dataframe = pd.read_csv(file_location, skiprows=[0], header=None)
    print(dataframe)
    return dataframe.iloc[:,9:]
# currently taking a single file
data_points = separate_data_points('../data/1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-b2c901550356> in <module>
#       8     return dataframe.iloc[:,9:]
#       9 # currently taking a single file
# ---> 10 data_points = separate_data_points('../data/1.csv')
#
# <ipython-input-4-b2c901550356> in separate_data_points(file_location)
#       4
#       5 def separate_data_points(file_location):
# ----> 6     dataframe = pd.read_csv(file_location, skiprows=[0], header=None)
#       7     print(dataframe)
#       8     return dataframe.iloc[:,9:]
#
# ...

# %%
# only for one data
# set offset to mean
required_data = data_points.iloc[0,:].to_numpy()
mean = np.mean(required_data)
required_data_without_offset = required_data - mean

# %%
dataframe = pd.read_csv('./1.csv', header=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-c904b4e5961e> in <module>
# ----> 1 dataframe = pd.read_csv('./1.csv', header=None)
#
# ~/miniconda3/envs/uni_project/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
# remove signal noise
data_without_signal_noise = required_data_without_offset.tolist()
n = 410
del data_without_signal_noise[:n]

# %%
peak = 0
peak_index = 0
for i,b in enumerate(data_without_signal_noise):
    if (abs(b)> peak):
        peak = b
        peak_index=i
cut_peak = data_without_signal_noise
DATA_SIZE = 200
n = peak_index - 200
del cut_peak[:n]
del cut_peak[200*2:]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(100, 90))
ax = fig.add_subplot(1,1,1)
# ax.set_xlim([600,1500])
ax.plot(cut_peak)
