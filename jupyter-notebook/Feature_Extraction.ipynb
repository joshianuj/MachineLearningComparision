# %%
import numpy as np
import pandas as pd
import xlrd

import matplotlib.pyplot as plt
from numpy.fft import fft, fftfreq, ifft, rfft

def fft_from_data_frame(data_frame):
    fs= 114e3
    signal_set = []
    for row in data_frame.values:
        fft_data = fft(row, n=row.size)/row.size
        freq = fftfreq(row.size, d=1/fs)
        cut_high_signal = np.abs(fft_data).copy()
        cut_high_signal[(freq > 50000)] = 0
        cut_high_signal[(freq < 30000)] = 0
        signal_without_0 = list(filter(lambda a: a != 0, cut_high_signal))
        signal_set.append(np.abs(signal_without_0))
    return signal_set

# %%
import glob

def get_fft_set(file_names):
    fft_set = []
    for front in file_names:
        data = pd.read_csv(front)
        fft_set = fft_data + fft_set
    return fft_set


def get_dataframe_row(file_name, row_extra_information=['Motorbike', 'None', 80]):
    data = pd.read_csv(file_name)
    fft_data = fft_from_data_frame(data)
    data_with_label = []
    for object in fft_data:
        object = object.tolist()
        object = row_extra_information + object
        data_with_label.append(object)
    return data_with_label
    
data_frame_row_set = None
type = ['Object', 'Object Property', 'Distance']
for i in range(1,91):
    type.append(f'features_{i}')
# file_name = f'./Documents/data_set/Result/26_Ford_Black_back/{i}_overall.csv'
for i in range(80,200,10):
    file_name = f'./Documents/data_set/Result/Wall_2/{i}_overall.csv'
    data_frame_row = get_dataframe_row(file_name, ['Wall', 'Concrete', i])
    if data_frame_row_set is not None:
        data_frame_row_set = data_frame_row_set + data_frame_row
    else:
        data_frame_row_set = data_frame_row
dataframe = pd.DataFrame(data_frame_row_set, columns=type)
dataframe.to_excel('./Documents/data_set/Result/Wall_2/feature_set.xls')
dataframe.to_csv('./Documents/data_set/Result/Wall_2/feature_set.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-fa5fdad9beac> in <module>
#      26 for i in range(80,200,10):
#      27     file_name = f'./Documents/data_set/Result/Wall_2/{i}_overall.csv'
# ---> 28     data_frame_row = get_dataframe_row(file_name, ['Wall', 'Concrete', i])
#      29     if data_frame_row_set is not None:
#      30         data_frame_row_set = data_frame_row_set + data_frame_row
#
# <ipython-input-3-fa5fdad9beac> in get_dataframe_row(file_name, row_extra_information)
#      10
#      11 def get_dataframe_row(file_name, row_extra_information=['Motorbike', 'None', 80]):
# ---> 12     data = pd.read_csv(file_name)
#      13     fft_data = fft_from_data_frame(data)
#      14     data_with_label = []
#
# ~/miniconda3/envs/uni_project/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     695                     skip_blank_lines=skip_blank_lines)
#     696
# --> 697         return _read(filepath_or_buffer, kwds)
#     698
#     699     parser_f.__name__ = name
#
# ~/miniconda3/envs/uni_project/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     422
#     423     # Create the parser.
# --> 424     parser = TextFileReader(filepath_or_buffer, **kwds)
#     425
#     426     if chunksize or iterator:
#
# ~/miniconda3/envs/uni_project/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     888             self.options['has_index_names'] = kwds['has_index_names']
#     889
# --> 890         self._make_engine(self.engine)
#     891
#     892     def close(self):
#
# ~/miniconda3/envs/uni_project/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1115     def _make_engine(self, engine='c'):
#    1116         if engine == 'c':
# -> 1117             self._engine = CParserWrapper(self.f, **self.options)
#    1118         else:
#    1119             if engine == 'python':
#
# ~/miniconda3/envs/uni_project/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    
# 3300  0.000518  0.000618  0.000584  0.000666  0.007158  0.001902
# 3301  0.000811  0.000592  0.000299  0.001310  0.007036  0.000507
# 3302  0.001122  0.000856  0.000764  0.000870  0.005921  0.003269
# 3303  0.000318  0.001074  0.000725  0.001412  0.007723  0.001259
# 3304  0.000439  0.000794  0.001168  0.001043  0.006833  0.001582
# 3305  0.000424  0.000965  0.000572  0.000984  0.007307  0.001840
# 3306  0.001081  0.000510  0.000993  0.000243  0.006841  0.001563
# 3307  0.001726  0.001368  0.000751  0.000573  0.007395  0.000852
# 3308  0.000647  0.000925  0.000875  0.001189  0.007620  0.001974
# 3309  0.001030  0.000213  0.000886  0.000991  0.008321  0.001440
# 3310  0.001295  0.000653  0.001335  0.001125  0.007944  0.000449
# 3311  0.000266  0.000370  0.001020  0.000573  0.006133  0.001405
# 3312  0.000390  0.001217  0.000308  0.001017  0.006341  0.000438
# 3313  0.000147  0.001152  0.001513  0.002515  0.007693  0.001570
# 3314  0.001496  0.000934  0.000657  0.000532  0.008061  0.000143
# 3315  0.000419  0.001540  0.000320  0.000609  0.005078  0.000543
# 3316  0.001591  0.001228  0.000263  0.000727  0.006234  0.000621
# 3317  0.000651  0.001265  0.001633  0.001963  0.007337  0.000651
# 3318  0.001676  0.001018  0.001370  0.001380  0.006519  0.001115
# 3319  0.000540  0.001211  0.001309  0.000743  0.006363  0.000341
#
# [3320 rows x 93 columns]

# %%
data_with_label = []
type = ['Object', 'Object Property', 'Distance']
for i in range(1,91):
    type.append(f'features_{i}')
for object in motorbike_1_fft:
    object = object.tolist()
    object.insert(0,'motorbike')
    object.insert(1,'None')
    object.insert(2,'80')
    data_with_label.append(object)
dataframe = pd.DataFrame(data_with_label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-566778a3ee87> in <module>
#       3 for i in range(1,91):
#       4     type.append(f'features_{i}')
# ----> 5 for object in motorbike_1_fft:
#       6     object = object.tolist()
#       7     object.insert(0,'motorbike')
#
# NameError: name 'motorbike_1_fft' is not defined

# %%
'a'.upper()
# Out:
# 'A'

# %%
files = glob.glob('./Documents/data_set/Result/Features/*.csv')

# %%
data = pd.read_csv(files[0])
header_value = np.delete(data.columns.values,0)

# %%
data_frame_collection = None
for f in files:
    data_frame = pd.read_csv(f, header=None, skiprows=[0])
    data_frame = data_frame.iloc[:,1:].values
    if data_frame_collection is not None:
        data_frame_collection = np.concatenate((data_frame_collection, data_frame))
    else:
        data_frame_collection = data_frame
data_frame_features = pd.DataFrame(data_frame_collection, columns=header_value)
data_frame_features.to_csv('./Documents/data_set/Result/Features/Overall/overall.csv')
data_frame_features.to_excel('./Documents/data_set/Result/Features/Overall/overall.xls')

# %%
data_frame = pd.read_csv(files[0], header=None, skiprows=[0])
data_frame_2 = pd.read_csv(files[1], header=None, skiprows=[0])

data_frame = data_frame.iloc[:,1:].values
data_frame_2 = data_frame_2.iloc[:,1:].values

# %%
np.concatenate((data_frame, data_frame_2)).shape
# Out:
# (6539, 93)

# %%
data_frame.shape
# Out:
# (3219, 93)

# %%
data_frame_2.shape
# Out:
# (3320, 93)
